# %%
import os
from tensorflow.keras.models import load_model

# Point to the cloned repository
model_path = 'Stock-Price-Movement-Prediction/best_enhanced_model.keras'

if os.path.exists(model_path):
    model = load_model(model_path)
    print("✅ Model loaded successfully!")
    print(model.summary())
else:
    print(f"❌ File not found: {model_path}")
# Out:
# 2026-05-10 15:46:46.048870: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ❌ File not found: Stock-Price-Movement-Prediction/best_enhanced_model.keras
