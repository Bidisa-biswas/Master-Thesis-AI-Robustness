# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from arch import arch_model # Calculating the GARCH model
import warnings
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
print("All imports ready!")
# Out:
# All imports ready!

# %%
from src.data_loader import SP500DataLoader

# Load data covering COVID period
loader_covid = SP500DataLoader(start_year=2005, end_year=2022)
df_covid = loader_covid.load_all()


print(f"Data loaded: {df_covid.index[0]} to {df_covid.index[-1]}")
print(f"Shape: {df_covid.shape}")
print(f"\nFirst 3 rows:")
print(df_covid.head(3))
# Out:
# Data loaded: 2005-01-03 00:00:00 to 2022-12-30 00:00:00
# Shape: (4531, 8)
#
# First 3 rows:
#               adj_close        close         high          low         open  \
# Date
# 2005-01-03  1202.079956  1202.079956  1217.800049  1200.319946  1211.920044
# 2005-01-04  1188.050049  1188.050049  1205.839966  1185.390015  1202.079956
# 2005-01-05  1183.739990  1183.739990  1192.729980  1183.719971  1188.050049
#
#                 volume   returns  log_returns
# Date
# 2005-01-03  1510800000       NaN          NaN
# 2005-01-04  1721000000 -0.011671    -0.011740
# 2005-01-05  1738900000 -0.003628    -0.003634

# %%
print(f"Pre-COVID returns: {len(pre_covid_returns)} days")
print(f"  From: {pre_covid_returns.index[0]} to {pre_covid_returns.index[-1]}")
print(f"  Mean return: {pre_covid_returns.mean():.4f}%")

print(f"\nCOVID crisis returns: {len(covid_crisis_returns)} days")
print(f"  From: {covid_crisis_returns.index[0]} to {covid_crisis_returns.index[-1]}")
print(f"  Mean return: {covid_crisis_returns.mean():.4f}%")
# Out:
# Pre-COVID returns: 2516 days
#   From: 2010-01-04 00:00:00 to 2019-12-31 00:00:00
#   Mean return: 0.0423%
#
# COVID crisis returns: 505 days
#   From: 2020-01-02 00:00:00 to 2021-12-31 00:00:00
#   Mean return: 0.0770%

# %%
def fit_gjr_garch(returns, period_name="Model"):
    """
    Fit GJR-GARCH(1,1) model and return parameters.
    Returns must be RAW log returns (~0.01 scale).
    Scaling to percent (×100) is applied ONCE, here, for numerical stability.
    """
    # Scale to percent for numerical stability — applied uniformly, in one place
    returns_scaled = returns * 100

    print(f"\n{'='*70}")
    print(f"FITTING GJR-GARCH: {period_name}")
    print(f"{'='*70}")
    print(f"Data points: {len(returns_scaled)}")
    print(f"Date range: {returns_scaled.index[0]} to {returns_scaled.index[-1]}")
    print(f"Mean return (scaled): {returns_scaled.mean():.6f}")
    print(f"Std deviation (scaled): {returns_scaled.std():.6f}")

    # Fit GJR-GARCH(1,1) with asymmetry term (o=1) on the SCALED series
    model = arch_model(
        returns_scaled,         
        vol='GARCH',
        p=1,
        q=1,
        o=1,                     # asymmetry term for the leverage effect
        dist='normal'
    )

    results = model.fit(update_freq=5, disp='off')

    params = {
        'omega': results.params['omega'],
        'alpha': results.params['alpha[1]'],
        'gamma': results.params['gamma[1]'],
        'beta': results.params['beta[1]'],
        'persistence': results.params['alpha[1]'] + results.params['beta[1]'] + results.params['gamma[1]'] / 2,
        'p_value_gamma': results.pvalues['gamma[1]'],
        'log_likelihood': results.loglikelihood,
        'aic': results.aic,
        'bic': results.bic
    }

    print(f"\n--- PARAMETERS ---")
    print(f"ω (omega) = {params['omega']:.6f}")
    print(f"α (alpha) = {params['alpha']:.4f}")
    print(f"γ (gamma) = {params['gamma']:.4f}  ← LEVERAGE EFFECT")
    print(f"β (beta)  = {params['beta']:.4f}")
    print(f"Persistence = {params['persistence']:.4f} (should be < 1)")

    if params['gamma'] > 0 and params['p_value_gamma'] < 0.05:
        print(f"LEVERAGE EFFECT CONFIRMED: γ = {params['gamma']:.4f}, p = {params['p_value_gamma']:.4f} < 0.05")
    elif params['gamma'] > 0:
        print(f"Leverage present but not significant (p = {params['p_value_gamma']:.4f})")
    else:
        print(f"No leverage effect detected (γ = {params['gamma']:.4f})")

    return params, results

# %%
# Fit GARCH on pre-COVID period (2010-2019)
params_pre_covid, results_pre_covid = fit_gjr_garch(pre_covid_returns, "PRE-COVID (2010-2019)")
# Out:
# ...
# FITTING GJR-GARCH: PRE-COVID (2010-2019)
# ...
# Data points: 2516
# Date range: 2010-01-04 00:00:00 to 2019-12-31 00:00:00
# Mean return (scaled): 4.228059
# Std deviation (scaled): 93.206575
#
# --- PARAMETERS ---
# ω (omega) = 357.330153
# α (alpha) = 0.0000
# γ (gamma) = 0.2793  ← LEVERAGE EFFECT
# β (beta)  = 0.8161
# Persistence = 0.9558 (should be < 1)
# LEVERAGE EFFECT CONFIRMED: γ = 0.2793, p = 0.0000 < 0.05

# %%
# Fit GARCH on COVID crisis period (2020-2021)
params_covid, results_covid = fit_gjr_garch(covid_crisis_returns, "COVID CRISIS (2020-2021)")
# Out:
# ...
# FITTING GJR-GARCH: COVID CRISIS (2020-2021)
# ...
# Data points: 505
# Date range: 2020-01-02 00:00:00 to 2021-12-31 00:00:00
# Mean return: 0.076994%
# Std deviation: 1.651391%
#
# --- PARAMETERS ---
# ω (omega) = 0.114953  (baseline volatility)
# α (alpha) = 0.1762  (reaction to past shock)
# γ (gamma) = 0.3328  (EXTRA reaction to BAD news) ← LEVERAGE EFFECT
# β (beta)  = 0.6238  (volatility persistence)
#
# Persistence = 0.9664 (should be < 1)
#
#  Leverage effect present but not significant (p = 0.1336)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from src.data_loader import SP500DataLoader
from arch import arch_model

# Create figures directory if it doesn't exist
figures_path = Path('../results/figures')
figures_path.mkdir(parents=True, exist_ok=True)

print("="*60)
print("COVID CRISIS GARCH PLOTS")
print(f"Saving to: {figures_path.absolute()}")
print("="*60)
# Out:
# ...
# COVID CRISIS GARCH PLOTS
# Saving to: /Users/bidisabiswas/PycharmProjects/Master-Thesis-AI-Robustness/thesis-ai-robustness/notebooks/../results/figures
# ...

# %%
print("\n3. GENERATING PLOT 1: Side-by-Side Comparison")
print("-"*40)

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Pre-COVID Volatility (2010-2019)
axes[0].plot(cond_vol_pre.index, cond_vol_pre, color='blue', linewidth=1)
axes[0].axhline(y=cond_vol_pre.mean(), color='red', linestyle='--', 
                label=f'Mean: {cond_vol_pre.mean():.2f}%')
axes[0].set_title('Pre-COVID Period (2010-2019): GJR-GARCH Conditional Volatility', fontsize=14)
axes[0].set_ylabel('Volatility (%)', fontsize=12)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# COVID Crisis Volatility (2020-2021)
axes[1].plot(cond_vol_covid.index, cond_vol_covid, color='red', linewidth=1)
axes[1].axhline(y=cond_vol_covid.mean(), color='blue', linestyle='--', 
                label=f'Mean: {cond_vol_covid.mean():.2f}%')
axes[1].set_title('COVID Crisis (2020-2021): GJR-GARCH Conditional Volatility', fontsize=14)
axes[1].set_ylabel('Volatility (%)', fontsize=12)
axes[1].set_xlabel('Date', fontsize=12)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(figures_path / 'garch_volatility_covid.png', dpi=150, bbox_inches='tight')
plt.show()
print(f"   ✓ Saved: {figures_path / 'garch_volatility_covid.png'}")
# Out:
# 3. GENERATING PLOT 1: Side-by-Side Comparison
# ----------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       4 fig, axes = plt.subplots(2, 1, figsize=(14, 10))
#       6 # Pre-COVID Volatility (2010-2019)
# ----> 7 axes[0].plot(cond_vol_pre.index, cond_vol_pre, color='blue', linewidth=1)
#       8 axes[0].axhline(y=cond_vol_pre.mean(), color='red', linestyle='--',
#       9                 label=f'Mean: {cond_vol_pre.mean():.2f}%')
#      10 axes[0].set_title('Pre-COVID Period (2010-2019): GJR-GARCH Conditional Volatility', fontsize=14)
#
# NameError: name 'cond_vol_pre' is not defined

# %%
print("\n3. GENERATING COVID GARCH PLOT")
print("-"*40)

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Pre-COVID Period (2010-2019)
axes[0].plot(cond_vol_pre.index, cond_vol_pre, color='blue', linewidth=1)
axes[0].axhline(y=cond_vol_pre.mean(), color='red', linestyle='--', 
                label=f'Mean Volatility: {cond_vol_pre.mean():.2f}%')
axes[0].set_title('Pre-COVID Period (2010-2019): GARCH(1,1) Conditional Volatility', fontsize=14)
axes[0].set_ylabel('Volatility (%)', fontsize=12)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# COVID Crisis Period (2020-2021)
axes[1].plot(cond_vol_covid.index, cond_vol_covid, color='red', linewidth=1)
axes[1].axhline(y=cond_vol_covid.mean(), color='blue', linestyle='--', 
                label=f'Mean Volatility: {cond_vol_covid.mean():.2f}%')
axes[1].set_title('COVID Crisis Period (2020-2021): GARCH(1,1) Conditional Volatility', fontsize=14)
axes[1].set_ylabel('Volatility (%)', fontsize=12)
axes[1].set_xlabel('Date', fontsize=12)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(figures_path / 'garch_volatility_covid.png', dpi=150, bbox_inches='tight')
plt.show()

print(f"   ✓ Saved: {figures_path / 'garch_volatility_covid.png'}")

# %%
print("\n" + "="*60)
print("VOLATILITY STATISTICS SUMMARY")
print("="*60)
print(f"Pre-COVID Period (2010-2019):")
print(f"  Mean Volatility: {cond_vol_pre.mean():.4f}%")
print(f"  Max Volatility:  {cond_vol_pre.max():.4f}%")
print(f"  Std Volatility:  {cond_vol_pre.std():.4f}%")

print(f"\nCOVID Crisis Period (2020-2021):")
print(f"  Mean Volatility: {cond_vol_covid.mean():.4f}%")
print(f"  Max Volatility:  {cond_vol_covid.max():.4f}%")
print(f"  Std Volatility:  {cond_vol_covid.std():.4f}%")

print(f"\nVolatility Increase: {cond_vol_covid.mean() / cond_vol_pre.mean():.2f}x")
print("="*60)

print(f"\n✅ Figure saved to: {figures_path / 'garch_volatility_covid.png'}")

# %%
p3, _ = fit_gjr_garch(df_covid['2010':'2019']['log_returns'].dropna(), "Pre-COVID")
p4, _ = fit_gjr_garch(df_covid['2020':'2021']['log_returns'].dropna(), "COVID Crisis")
# Out:
# ...
# FITTING GJR-GARCH: Pre-COVID
# ...
# Data points: 2516
# Date range: 2010-01-04 00:00:00 to 2019-12-31 00:00:00
# Mean return (scaled): 0.042281
# Std deviation (scaled): 0.932066
#
# --- PARAMETERS ---
# ω (omega) = 0.035730
# α (alpha) = 0.0000
# γ (gamma) = 0.2793  ← LEVERAGE EFFECT
# β (beta)  = 0.8161
# Persistence = 0.9558 (should be < 1)
# LEVERAGE EFFECT CONFIRMED: γ = 0.2793, p = 0.0000 < 0.05
#
# ...
# FITTING GJR-GARCH: COVID Crisis
# ...
# Data points: 505
# Date range: 2020-01-02 00:00:00 to 2021-12-31 00:00:00
# Mean return (scaled): 0.076994
# Std deviation (scaled): 1.651391
#
# --- PARAMETERS ---
# ω (omega) = 0.114953
# α (alpha) = 0.1762
# γ (gamma) = 0.3328  ← LEVERAGE EFFECT
# β (beta)  = 0.6238
# Persistence = 0.9664 (should be < 1)
# Leverage present but not significant (p = 0.1336)
